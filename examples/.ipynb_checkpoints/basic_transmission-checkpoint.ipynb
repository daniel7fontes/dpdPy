# %% [markdown]
# # A-RoF transmission

# %%
import sys
from pathlib import Path

file_path    = str(Path.cwd())
project_path = str(Path.cwd().parent)

sys.path.append(project_path)

# %%
import pickle 
import torch as th
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal             import welch, firwin
from tqdm.notebook            import tqdm
from tabulate                 import tabulate

from optic.comm.ofdm          import modulateOFDM, demodulateOFDM
from optic.comm.modulation    import modulateGray
from optic.comm.metrics       import fastBERcalc, calcEVM
from optic.dsp.core           import pnorm, finddelay, decimate, clockSamplingInterp
from optic.dsp.coreGPU        import firFilter
from optic.utils              import parameters

from dpd.channel_models import RoF_channel
from dpd.utils import calcACLR, applyDPD
from dpd.nn import trainNN, trainMP
from dpd.plots import plotConst, plotSpec

# %%
font = {'size':16}
plt.rc('font', **font)
plt.rcParams["font.family"] = "serif"

# %% [markdown]
# ### 1 - OFDM signal generation

# %%
# Parâmetros de modulação
modOrder  = 64                 # Modulation order
constType = 'qam'              # Constellation format
Rb = 5e9                       # Bitrate
SpS = 32

# OFDM parameters
paramOFDM = parameters()
paramOFDM.G   = 32              
paramOFDM.SpS = SpS

paramOFDM.Nfft = 2**10
paramOFDM.nullCarriers  = np.array([paramOFDM.Nfft//2], dtype = np.int64)
paramOFDM.pilotCarriers = np.linspace(0, paramOFDM.Nfft - 1, 32, dtype = np.int64)

Nz = len(paramOFDM.nullCarriers)
Np = len(paramOFDM.pilotCarriers)
Ni = paramOFDM.Nfft - Nz - Np
numOFDMframes = 100

# %%
# Bits generation
np.random.seed(2)
bits = np.random.randint(2, size = (numOFDMframes*Ni, int(np.log2(modOrder))))

# Symbols modulation
symbTx = modulateGray(bits, modOrder, constType)
symbTx = pnorm(symbTx)

pilotSymb = 0.25*(max(symbTx.real) + 1j*max(symbTx.imag))
paramOFDM.pilot = pilotSymb

# %%
# OFDM signal generation
sigTx = modulateOFDM(symbTx, paramOFDM)
sigTx = pnorm(sigTx)

Rs = Rb / ( Ni / (paramOFDM.Nfft + paramOFDM.G) * np.log2(modOrder))
Fs = Rs * paramOFDM.SpS

t = np.arange(0, sigTx.size)*1/Fs
t_CP   = paramOFDM.SpS * paramOFDM.G * (1/Fs)
t_symb = paramOFDM.SpS * (paramOFDM.Nfft + paramOFDM.G) * (1/Fs)

# %%
table = [['Grandeza', 'Parâmetro', 'Valor'],
         ['Sampling rate', 'Fs', f'{Fs*1e-9:.2f} Gsamples/s'],
         ['Symbol rate', 'Rs', f'{Rs*1e-9:.2f} Gsymb/s'],
         ['Bit rate', 'Rb', f'{Rb*1e-9:.2f} GHz'],
         ['Ordem da constelação', 'M', f'{modOrder}'],
         ['Nfft', 'Nfft', f'{paramOFDM.Nfft}'],
         ['Cyclic prefix length', 'G', f'{paramOFDM.G}'],
         ['Number of information subcarriers', 'Ni', f'{Ni}'],
         ['Number of pilot subcarriers', 'Np', f'{Np}'],
         ['Number of null subcarriers', 'Nz', f'{Nz}'],
         ['Subcarriers spacing', 'Delta_f', f'{(Rs/paramOFDM.Nfft)*1e-3:.2f} kHz'],
         ['OFDM symbol period', 'T_symb', f'{1e6*t_symb:.2f} us'],
         ['Cyclic prefix duration', 'T_CP', f'{1e6*t_CP:.2f} us'] ]

print(tabulate(table, headers = 'firstrow', tablefmt = 'fancy_grid'))
# Out:
# ╒═══════════════════════════════════╤═════════════╤══════════════════╕
# │ Grandeza                          │ Parâmetro   │ Valor            │
# ╞═══════════════════════════════════╪═════════════╪══════════════════╡
# │ Sampling rate                     │ Fs          │ 28.42 Gsamples/s │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Symbol rate                       │ Rs          │ 0.89 Gsymb/s     │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Bit rate                          │ Rb          │ 5.00 GHz         │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Ordem da constelação              │ M           │ 64               │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Nfft                              │ Nfft        │ 1024             │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Cyclic prefix length              │ G           │ 32               │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Number of information subcarriers │ Ni          │ 991              │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Number of pilot subcarriers       │ Np          │ 32               │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Number of null subcarriers        │ Nz          │ 1                │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Subcarriers spacing               │ Delta_f     │ 867.18 kHz       │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ OFDM symbol period                │ T_symb      │ 1.19 us          │
# ├───────────────────────────────────┼─────────────┼──────────────────┤
# │ Cyclic prefix duration            │ T_CP        │ 0.04 us          │
# ╘═══════════════════════════════════╧═════════════╧══════════════════╛

# %% [markdown]
# ### 2 - A-RoF channel

# %%
# MZM parameters
paramMZM = parameters()
paramMZM.Vpi = 3
paramMZM.Vb = -paramMZM.Vpi*0.5
paramMZM.P_laser = 0
paramMZM.Pin_MZM = 17

# RF parameters
paramRF = parameters()
paramRF.fc_e = 3.55e9
paramRF.bw = Rs
paramRF.Fs = Fs

# Optical fiber parameters
paramFiber = parameters()
paramFiber.L = 20
paramFiber.alpha = 0.2
paramFiber.D = 16
paramFiber.Fc = 193.1e12
paramFiber.Fs = Fs

# Photodiode parameters
paramPD = parameters()
paramPD.ideal = False
paramPD.B = paramRF.fc_e + 2*Rs
paramPD.Ipd_sat = 50e-3
paramPD.Fs = Fs

# PA parameters
paramPA = parameters()
paramPA.model_name = "modified_rapp"
paramPA.g = 16
paramPA.x_sat = 1.9
paramPA.sigma_p = 1.1
paramPA.alpha = -345
paramPA.beta = 0.17
paramPA.q = 4

# %%
paramRoF = parameters()
paramRoF.paramMZM = paramMZM
paramRoF.paramRF = paramRF
paramRoF.paramFiber = paramFiber
paramRoF.paramPD = paramPD
paramRoF.paramPA = paramPA

sigRx_PA = RoF_channel(sigTx, paramRoF, filter_numtaps = 4096)

# %%
hlp = firwin(4096, Rs/1.75, fs = Fs)
sigRx = firFilter(hlp, sigRx_PA)

delay = finddelay(sigRx, sigTx)
sigRx = np.roll(sigRx, -delay)

rot = np.mean(sigTx/sigRx)
sigRx = rot/np.abs(rot)*sigRx

# Parâmetros da decimação
paramDec = parameters()
paramDec.SpS_in  = paramOFDM.SpS
paramDec.SpS_out = 1

symbRx_OFDM = decimate(sigRx, paramDec).ravel()
symbRx = demodulateOFDM(symbRx_OFDM, paramOFDM)

# %%
discard = 100
index = np.arange(discard, symbTx.size - discard)

BER, _, _ = fastBERcalc(symbRx[index], symbTx[index], modOrder, constType)
EVM = np.sqrt(calcEVM(symbRx, modOrder, constType))*100

print(f"BER = {BER[0]:.5f} \nEVM = {EVM[0]:.3f} %")

# Plot normalization
symbTx = pnorm(symbTx)
symbRx = pnorm(symbRx)

plotConst(symbTx, symbRx, axs_lim = 1.5)
# Out:
# BER = 0.01100
# EVM = 9.804 %

# %%
freq, P_sigTx    = welch(pnorm(sigTx)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)
freq, P_sigRx_PA = welch(pnorm(sigRx_PA)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)

print(f"SigTx - ACLR = {calcACLR(P_sigTx, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/o DPD - ACLR = {calcACLR(P_sigRx_PA, freq, Rs/2, 10e6):.3f} dB")

plotSpec(freq, P_sigTx, P_sigRx_PA, label = "No DPD")
# Out:
# SigTx - ACLR = -31.304 dB
# SigRx PA w/o DPD - ACLR = -24.978 dB

# %% [markdown]
# ### 3 - Prepare data for DPD training (ILA)

# %%
SpS_DPD = 4
Fs_DPD = Fs * SpS_DPD / SpS

hlp = firwin(4096, SpS_DPD*Rs/2, fs = Fs)

sigRef = clockSamplingInterp(pnorm(firFilter(hlp, sigTx).reshape(-1, 1)), Fs, Fs_DPD).ravel()
sigIn  = clockSamplingInterp(pnorm(firFilter(hlp, sigRx_PA).reshape(-1, 1)), Fs, Fs_DPD).ravel()

delay = finddelay(sigIn, sigRef)
sigIn = np.roll(sigIn, -delay)

rot = np.mean(sigRef/sigIn)
sigIn = rot/np.abs(rot)*sigIn

# %% [markdown]
# ### 4 - Transmission with DPD-ARVTDNN

# %%
paramModel = parameters()
paramModel.model_name = "ARVTDNN"
paramModel.K = 3
paramModel.M = 3
paramModel.hidden_layers = [16, 8]
paramModel.activation = "relu"

paramTrain = parameters()
paramTrain.trainTestFrac = 0.75
paramTrain.batchSize     = 1_000
paramTrain.shuffle       = False
paramTrain.adaptLearningRatio = True
paramTrain.lr      = 5e-3
paramTrain.epochs  = 500
paramTrain.pgrsBar = True
paramTrain.device  = "cuda" # "cpu"

model_ARVTDNN, trainLoss, testLoss = trainNN(th.from_numpy(sigIn[0:50_000]).to(paramTrain.device).type(th.complex64),  \
                                             th.from_numpy(sigRef[0:50_000]).to(paramTrain.device).type(th.complex64), \
                                             paramTrain, paramModel)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(figsize = (7, 4))
axs.plot(10*np.log10(trainLoss), color = "k", label = "Train loss")
axs.plot(10*np.log10(testLoss), "--", color = "gray", label = "Test loss")

axs.set_xlim(1, paramTrain.epochs - 1)
axs.set_ylabel("MSE [dB]")
axs.set_xlabel("Epoch")
axs.grid()
axs.legend(fontsize = 14, framealpha = 1)
plt.tight_layout()

# %%
sigTx_ARVTDNN, gain_ARVTDNN = applyDPD(sigTx, model_ARVTDNN, Rs, Fs, Fs_DPD, paramTrain, paramModel)
paramRoF.paramMZM.Pin_MZM = 17 + gain_ARVTDNN

sigRx_PA_ARVTDNN = RoF_channel(sigTx_ARVTDNN, paramRoF, filter_numtaps = 4096)

# %%
# Filtering and delay correction
hlp = firwin(4096, Rs/1.75, fs = Fs)
sigRx_ARVTDNN = firFilter(hlp, sigRx_PA_ARVTDNN)

delay = finddelay(sigRx_ARVTDNN, sigTx)
sigRx_ARVTDNN = np.roll(sigRx_ARVTDNN, -delay)

rot = np.mean(sigTx/sigRx_ARVTDNN)
sigRx_ARVTDNN = rot/np.abs(rot)*sigRx_ARVTDNN

# Decimation
paramDec = parameters()
paramDec.SpS_in  = SpS
paramDec.SpS_out = 1

symbRx_OFDM = decimate(sigRx_ARVTDNN, paramDec).ravel()
symbRx_ARVTDNN  = demodulateOFDM(symbRx_OFDM, paramOFDM)

# %%
discard = 100
index = np.arange(discard, symbTx.size - discard)

BER, _, _ = fastBERcalc(symbRx_ARVTDNN[index], symbTx[index], modOrder, constType)
EVM = np.sqrt(calcEVM(symbRx_ARVTDNN[index], modOrder, constType))*100

print(f"BER = {BER[0]:.5f} \nEVM = {EVM[0]:.3f} %")

symbRx_ARVTDNN = pnorm(symbRx_ARVTDNN)

plotConst(symbTx, [symbRx, symbRx_ARVTDNN], axs_lim = 1.5)
# Out:
# BER = 0.00009
# EVM = 5.133 %

# %%
freq, P_sigTx    = welch(pnorm(sigTx)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)
freq, P_sigRx_PA_ARVTDNN = welch(pnorm(sigRx_PA_ARVTDNN)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)

print(f"SigTx - ACLR = {calcACLR(P_sigTx, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/o DPD - ACLR = {calcACLR(P_sigRx_PA, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/ DPD-ARVTDNN - ACLR = {calcACLR(P_sigRx_PA_ARVTDNN, freq, Rs/2, 10e6):.3f} dB")

plotSpec(freq, P_sigTx, [P_sigRx_PA, P_sigRx_PA_ARVTDNN], label = ["No DPD", "w DPD"])
# Out:
# SigTx - ACLR = -31.304 dB
# SigRx PA w/o DPD - ACLR = -24.978 dB
# SigRx PA w/ DPD-ARVTDNN - ACLR = -27.375 dB

# %% [markdown]
# ### 5 - Transmission with DPD-ETDNN

# %%
paramModel = parameters()
paramModel.model_name = "ETDNN"
paramModel.N = 10
paramModel.M = 1
paramModel.activation = "relu"

paramTrain = parameters()
paramTrain.trainTestFrac = 0.75
paramTrain.batchSize     = 1_000
paramTrain.shuffle       = False
paramTrain.adaptLearningRatio = True
paramTrain.lr      = 5e-3
paramTrain.epochs  = 500
paramTrain.pgrsBar = True
paramTrain.device  = "cuda" # "cpu"

model_ETDNN, trainLoss, testLoss = trainNN(th.from_numpy(sigIn[0:50_000]).to(paramTrain.device).type(th.complex64),  \
                                           th.from_numpy(sigRef[0:50_000]).to(paramTrain.device).type(th.complex64), \
                                           paramTrain, paramModel)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(figsize = (7, 4))
axs.plot(10*np.log10(trainLoss), color = "k", label = "Train loss")
axs.plot(10*np.log10(testLoss), "--", color = "gray", label = "Test loss")

axs.set_xlim(1, paramTrain.epochs - 1)
axs.set_ylabel("MSE [dB]")
axs.set_xlabel("Epoch")
axs.grid()
axs.legend(fontsize = 14, framealpha = 1)
plt.tight_layout()

# %%
sigTx_ETDNN, gain_ETDNN = applyDPD(sigTx, model_ETDNN, Rs, Fs, Fs_DPD, paramTrain, paramModel)
paramRoF.paramMZM.Pin_MZM = 17 + gain_ETDNN

sigRx_PA_ETDNN = RoF_channel(sigTx_ETDNN, paramRoF, filter_numtaps = 4096)

# %%
# Filtering and delay correction
hlp = firwin(4096, Rs/1.75, fs = Fs)
sigRx_ETDNN = firFilter(hlp, sigRx_PA_ETDNN)

delay = finddelay(sigRx_ETDNN, sigTx)
sigRx_ETDNN = np.roll(sigRx_ETDNN, -delay)

rot = np.mean(sigTx/sigRx_ETDNN)
sigRx_ETDNN = rot/np.abs(rot)*sigRx_ETDNN

# Decimation
paramDec = parameters()
paramDec.SpS_in  = SpS
paramDec.SpS_out = 1

symbRx_OFDM = decimate(sigRx_ETDNN, paramDec).ravel()
symbRx_ETDNN  = demodulateOFDM(symbRx_OFDM, paramOFDM)

# %%
discard = 100
index = np.arange(discard, symbTx.size - discard)

BER, _, _ = fastBERcalc(symbRx_ETDNN[index], symbTx[index], modOrder, constType)
EVM = np.sqrt(calcEVM(symbRx_ETDNN[index], modOrder, constType))*100

print(f"BER = {BER[0]:.5f} \nEVM = {EVM[0]:.3f} %")

symbRx_ETDNN = pnorm(symbRx_ETDNN)

plotConst(symbTx, [symbRx, symbRx_ETDNN], axs_lim = 1.5)
# Out:
# BER = 0.00000
# EVM = 3.880 %

# %%
freq, P_sigTx    = welch(pnorm(sigTx)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)
freq, P_sigRx_PA_ETDNN = welch(pnorm(sigRx_PA_ETDNN)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)

print(f"SigTx - ACLR = {calcACLR(P_sigTx, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/o DPD - ACLR = {calcACLR(P_sigRx_PA, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/ DPD-ETDNN - ACLR = {calcACLR(P_sigRx_PA_ETDNN, freq, Rs/2, 10e6):.3f} dB")

plotSpec(freq, P_sigTx, [P_sigRx_PA, P_sigRx_PA_ETDNN], label = ["No DPD", "w DPD"])
# Out:
# SigTx - ACLR = -31.304 dB
# SigRx PA w/o DPD - ACLR = -24.978 dB
# SigRx PA w/ DPD-ETDNN - ACLR = -28.406 dB

# %% [markdown]
# ### 6 - Transmission with DPD-ETDKAN

# %%
paramModel = parameters()
paramModel.model_name = "ETDKAN"
paramModel.N = 1
paramModel.M = 1
paramModel.k = 2
paramModel.grid = 2
paramModel.seed = 0

paramTrain = parameters()
paramTrain.trainTestFrac = 0.75
paramTrain.batchSize     = 1_000
paramTrain.shuffle       = False
paramTrain.adaptLearningRatio = True
paramTrain.lr      = 5e-3
paramTrain.epochs  = 100
paramTrain.pgrsBar = True
paramTrain.device  = "cuda" # "cpu"
paramTrain.symbolicEpoch = 50

model_ETDKAN, trainLoss, testLoss = trainNN(th.from_numpy(sigIn[0:50_000]).to(paramTrain.device).type(th.complex64),  \
                                            th.from_numpy(sigRef[0:50_000]).to(paramTrain.device).type(th.complex64), \
                                            paramTrain, paramModel)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(figsize = (7, 4))
axs.plot(10*np.log10(trainLoss), color = "k", label = "Train loss")
axs.plot(10*np.log10(testLoss), "--", color = "gray", label = "Test loss")

axs.set_xlim(1, paramTrain.epochs - 1)
axs.set_ylabel("MSE [dB]")
axs.set_xlabel("Epoch")
axs.grid()
axs.legend(fontsize = 14, framealpha = 1)
plt.tight_layout()

# %%
sigTx_ETDKAN, gain_ETDKAN = applyDPD(sigTx, model_ETDKAN, Rs, Fs, Fs_DPD, paramTrain, paramModel)
paramRoF.paramMZM.Pin_MZM = 17 + gain_ETDKAN

sigRx_PA_ETDKAN = RoF_channel(sigTx_ETDKAN, paramRoF, filter_numtaps = 4096)

# %%
# Filtering and delay correction
hlp = firwin(4096, Rs/1.75, fs = Fs)
sigRx_ETDKAN = firFilter(hlp, sigRx_PA_ETDKAN)

delay = finddelay(sigRx_ETDKAN, sigTx)
sigRx_ETDKAN = np.roll(sigRx_ETDKAN, -delay)

rot = np.mean(sigTx/sigRx_ETDKAN)
sigRx_ETDKAN = rot/np.abs(rot)*sigRx_ETDKAN

# Decimation
paramDec = parameters()
paramDec.SpS_in  = SpS
paramDec.SpS_out = 1

symbRx_OFDM = decimate(sigRx_ETDKAN, paramDec).ravel()
symbRx_ETDKAN  = demodulateOFDM(symbRx_OFDM, paramOFDM)

# %%
discard = 100
index = np.arange(discard, symbTx.size - discard)

BER, _, _ = fastBERcalc(symbRx_ETDKAN[index], symbTx[index], modOrder, constType)
EVM = np.sqrt(calcEVM(symbRx_ETDKAN[index], modOrder, constType))*100

print(f"BER = {BER[0]:.5f} \nEVM = {EVM[0]:.3f} %")

symbRx_ETDKAN = pnorm(symbRx_ETDKAN)

plotConst(symbTx, [symbRx, symbRx_ETDKAN], axs_lim = 1.5)
# Out:
# BER = 0.00000
# EVM = 3.742 %

# %%
freq, P_sigTx    = welch(pnorm(sigTx)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)
freq, P_sigRx_PA_ETDKAN = welch(pnorm(sigRx_PA_ETDKAN)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)

print(f"SigTx - ACLR = {calcACLR(P_sigTx, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/o DPD - ACLR = {calcACLR(P_sigRx_PA, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/ DPD-ETDKAN - ACLR = {calcACLR(P_sigRx_PA_ETDKAN, freq, Rs/2, 10e6):.3f} dB")

plotSpec(freq, P_sigTx, [P_sigRx_PA, P_sigRx_PA_ETDKAN], label = ["No DPD", "w DPD"])
# Out:
# SigTx - ACLR = -31.304 dB
# SigRx PA w/o DPD - ACLR = -24.978 dB
# SigRx PA w/ DPD-ETDKAN - ACLR = -28.294 dB

# %% [markdown]
# ### 7 - Transmission with DPD-MP

# %%
M = 2
P = 3

paramModel = parameters()
paramModel.model_name = "MP"
paramModel.M = M
paramModel.P = P

paramTrain = parameters()
paramTrain.epochs = 5
paramTrain.mu  = 1e-3
paramTrain.lbd = 0.9999
paramTrain.S   = np.eye(paramModel.P*(paramModel.M + 1), dtype = complex)*5e-2
paramTrain.alg = "RLS"
paramTrain.pgrsBar = True

model_MP, trainLoss = trainMP(sigIn[0:50_000], sigRef[0:50_000], paramTrain, paramModel)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(figsize = (7, 4))
axs.plot(np.arange(1, paramTrain.epochs + 1), 10*np.log10(trainLoss), color = "k", label = "Train loss")

axs.set_xlim(1, paramTrain.epochs)
axs.set_ylabel("MSE [dB]")
axs.set_xlabel("Epoch")
axs.grid()
axs.legend(fontsize = 14, framealpha = 1)
plt.tight_layout()

# %%
sigTx_MP, gain_MP = applyDPD(sigTx, model_MP, Rs, Fs, Fs_DPD, paramTrain, paramModel)
paramRoF.paramMZM.Pin_MZM = 17 + gain_MP

sigRx_PA_MP = RoF_channel(sigTx_MP, paramRoF, filter_numtaps = 4096)

# %%
# Filtering and delay correction
hlp = firwin(4096, Rs/1.75, fs = Fs)
sigRx_MP = firFilter(hlp, sigRx_PA_MP)

delay = finddelay(sigRx_MP, sigTx)
sigRx_MP = np.roll(sigRx_MP, -delay)

rot = np.mean(sigTx/sigRx_MP)
sigRx_MP = rot/np.abs(rot)*sigRx_MP

# Decimation
paramDec = parameters()
paramDec.SpS_in  = SpS
paramDec.SpS_out = 1

symbRx_OFDM = decimate(sigRx_MP, paramDec).ravel()
symbRx_MP   = demodulateOFDM(symbRx_OFDM, paramOFDM)

# %%
discard = 100
index = np.arange(discard, symbTx.size - discard)

BER, _, _ = fastBERcalc(symbRx_MP[index], symbTx[index], modOrder, constType)
EVM = np.sqrt(calcEVM(symbRx_MP[index], modOrder, constType))*100

print(f"BER = {BER[0]:.5f} \nEVM = {EVM[0]:.3f} %")

symbRx_MP = pnorm(symbRx_MP)

plotConst(symbTx, [symbRx, symbRx_MP], axs_lim = 1.5)
# Out:
# BER = 0.00000
# EVM = 3.940 %

# %%
freq, P_sigTx    = welch(pnorm(sigTx)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)
freq, P_sigRx_PA_MP = welch(pnorm(sigRx_PA_MP)[0::paramOFDM.SpS//4], fs = 4*Rs, nfft = 16*1024, return_onesided = False)

print(f"SigTx - ACLR = {calcACLR(P_sigTx, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/o DPD - ACLR = {calcACLR(P_sigRx_PA, freq, Rs/2, 10e6):.3f} dB")
print(f"SigRx PA w/ DPD-MP - ACLR = {calcACLR(P_sigRx_PA_MP, freq, Rs/2, 10e6):.3f} dB")

plotSpec(freq, P_sigTx, [P_sigRx_PA, P_sigRx_PA_MP], label = ["No DPD", "w DPD"])
# Out:
# SigTx - ACLR = -31.304 dB
# SigRx PA w/o DPD - ACLR = -24.978 dB
# SigRx PA w/ DPD-MP - ACLR = -28.876 dB

# %%
plotSpec(freq, P_sigTx, [P_sigRx_PA, P_sigRx_PA_ARVTDNN, P_sigRx_PA_ETDNN, P_sigRx_PA_ETDKAN, P_sigRx_PA_MP], \
         label = ["No DPD", "ARVTDNN", "ETDNN", "ETDKAN", "MP"])
