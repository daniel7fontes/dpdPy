# %% [markdown]
# # A-RoF KAN-DPD - Hyperparameters optimization with Optuna

# %%
import sys

project_path = r"C:\Users\PC\Documents\Mestrado\DPD"
file_path    = project_path + r"\Optuna_studies\DPD_KAN"

sys.path.append(project_path)
sys.path.append(file_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch as th
import optuna

from torch                    import nn
from scipy.signal             import welch, firwin, hilbert
from scipy.constants          import pi
from tqdm.notebook            import tqdm
from tabulate                 import tabulate
from functools                import partial

from optic.comm.ofdm          import modulateOFDM, demodulateOFDM
from optic.comm.modulation    import modulateGray
from optic.models.channels    import linearFiberChannel
from optic.models.devices     import mzm, photodiode
from optic.comm.metrics       import fastBERcalc, calcEVM
from optic.dsp.core           import pnorm, signal_power, upsample, pulseShape, decimate, finddelay
from optic.dsp.coreGPU        import firFilter
from optic.utils              import parameters, dBm2W
from optic_private.dsp.core   import calcACLR
from optic_private.torchUtils import fitFilterNN

from dpd.nn                   import KAN_training
from dpd.utils                import power_amplifier
from dpd.plots                import calc_per_carrier
from dpd.optuna_tasks         import objective_dpd, get_pareto

from optuna.trial             import TrialState
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
font = {'size':14}
plt.rc('font', **font)
plt.rcParams["font.family"] = "serif"

# %% [markdown]
# ### 1 - Geração do Sinal OFDM

# %%
device = "cuda"
includeMemory = True

# Parâmetros de modulação
Rb = 5e9                               # Taxa de transmissão de bits
SpS = 32                               # Amostras por símbolo

# Parâmetros OFDM
paramOFDM = parameters()
paramOFDM.modOrder = 64                # Ordem da modulação
paramOFDM.modType  = 'qam'             # Tipo de modulação
paramOFDM.Nfft = 1024                  # Tam. da FFT
paramOFDM.G    = 32                   # Tam. do prefixo cíclico
paramOFDM.hermitSymmetry = False
paramOFDM.SpS = SpS

if paramOFDM.hermitSymmetry:
    Ns = paramOFDM.Nfft//2 - 1
    paramOFDM.pilotCarriers = np.linspace(0, Ns - 1, 8, dtype = np.int64)
    paramOFDM.nullCarriers  = np.array([], dtype = np.int64)
else:
    Ns = paramOFDM.Nfft
    paramOFDM.pilotCarriers = np.linspace(0, Ns - 1, 8, dtype = np.int64)
    paramOFDM.nullCarriers  = np.array([paramOFDM.Nfft//2], dtype = np.int64)

# Núm. de subportadoras de informação
Np = paramOFDM.pilotCarriers.size
Nz = paramOFDM.nullCarriers.size
Ni = Ns - Np - Nz
paramOFDM.Ni = Ni

Rs = Rb / ( Ni/(paramOFDM.Nfft + paramOFDM.G) * np.log2(paramOFDM.modOrder) )    # Taxa de transmissão de símbolos
Fs  = Rs * SpS                                                          # Taxa de amostragem

# Geração dos bits e dos símbolos QAM
numOFDMframes = 50
np.random.seed(2)
bits = np.random.randint(2, size = (numOFDMframes*Ni, int(np.log2(paramOFDM.modOrder))))

symbTx = modulateGray(bits, paramOFDM.modOrder, paramOFDM.modType)
symbTx = pnorm(symbTx)

pilotSymb = 0.25*(max(symbTx.real) + 1j*max(symbTx.imag))
paramOFDM.pilot = pilotSymb

# %%
sigTx = modulateOFDM(symbTx, paramOFDM)
sigTx = pnorm(sigTx)

t = np.arange(0, len(sigTx))*1/Fs
t_CP   = SpS * paramOFDM.G * (1/Fs)
t_symb = SpS * (paramOFDM.Nfft + paramOFDM.G) * (1/Fs)

# %%
table = [['Grandeza', 'Parâmetro', 'Valor'],
         ['Taxa de amostragem', 'Fs', f'{Fs*1e-9:.2f} Gsamples/s'],
         ['Taxa de símbolos', 'Rs', f'{Rs*1e-9:.2f} Gsymb/s'],
         ['Taxa de transmissão', 'Rb', f'{Rb*1e-9:.2f} Gb/s'],
         ['Ordem da constelação', 'M', f'{paramOFDM.modOrder}'],
         ['Tamanho da FFT', 'Nfft', f'{paramOFDM.Nfft}'],
         ['Tamanho do prefixo cíclico', 'G', f'{paramOFDM.G}'],
         ['Num. port. de informação', 'Ns', f'{Ni}'],
         ['Num. port. piloto', 'Np', f'{Np}'],
         ['Num. port. nulas', 'Nz', f'{Nz}'],
         ['Espaçamento entre subportadoras', 'Delta_f', f'{(Rs/paramOFDM.Nfft)*1e-6:.2f} MHz'],
         ['Duração do símbolo OFDM', 'T_symb', f'{1e9*t_symb:.2f} ns'],
         ['Duração do prefixo cíclico', 'T_CP', f'{1e9*t_CP:.2f} ns'] ]

print(tabulate(table, headers = 'firstrow', tablefmt = 'fancy_grid'))
# Out:
# ╒═════════════════════════════════╤═════════════╤══════════════════╕
# │ Grandeza                        │ Parâmetro   │ Valor            │
# ╞═════════════════════════════════╪═════════════╪══════════════════╡
# │ Taxa de amostragem              │ Fs          │ 27.74 Gsamples/s │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Taxa de símbolos                │ Rs          │ 0.87 Gsymb/s     │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Taxa de transmissão             │ Rb          │ 5.00 Gb/s        │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Ordem da constelação            │ M           │ 64               │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Tamanho da FFT                  │ Nfft        │ 1024             │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Tamanho do prefixo cíclico      │ G           │ 32               │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Num. port. de informação        │ Ns          │ 1015             │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Num. port. piloto               │ Np          │ 8                │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Num. port. nulas                │ Nz          │ 1                │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Espaçamento entre subportadoras │ Delta_f     │ 0.85 MHz         │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Duração do símbolo OFDM         │ T_symb      │ 1218.00 ns       │
# ├─────────────────────────────────┼─────────────┼──────────────────┤
# │ Duração do prefixo cíclico      │ T_CP        │ 36.91 ns         │
# ╘═════════════════════════════════╧═════════════╧══════════════════╛

# %%
## Parametrização dos dispositivos

# Parâmetros do MZM
paramMZM = parameters()
paramMZM.Vpi = 3
paramMZM.Vb = -paramMZM.Vpi/2
paramMZM.Pin_OF = 10

# Parâmetros do canal óptico
paramChannel = parameters()
paramChannel.L = 25
paramChannel.alpha = 0.2
paramChannel.D = 16
paramChannel.Fc = 193.1e12
paramChannel.Fs = Fs

#
paramRF = parameters()
paramRF.fc_e = 7.5e9
paramRF.Pin_RF = 17
paramRF.Pin_PA = 5

# Parâmetros do fotodiodo
paramPD = parameters()
paramPD.ideal = False
paramPD.B = paramRF.fc_e + 2*Rs
paramPD.Ipd_sat = 50e-3
paramPD.Fs = Fs

# %% [markdown]
# ### 2 Canal RoF

# %%
# Sinal RF
sigTx_RF = np.real( sigTx * np.exp(1j*2*pi*paramRF.fc_e*t) )

gain_pre_MZM = 10**( np.log10(dBm2W(paramRF.Pin_RF)/signal_power(sigTx_RF))/2)
sigTx_RF *= gain_pre_MZM
sigTx_RF = np.clip(sigTx_RF, -paramMZM.Vpi/2, paramMZM.Vpi/2)

# Sinal óptico
Ai     = np.sqrt(dBm2W(paramMZM.Pin_OF))*np.ones(sigTx_RF.size)
sigTxo = mzm(Ai, sigTx_RF, paramMZM)

numtaps = 4096
hopt_tx = firwin(numtaps, paramRF.fc_e + 2*Rs, fs = Fs)
sigTxo = np.sqrt(signal_power(sigTxo))*pnorm(firFilter(hopt_tx, sigTxo))

sigRxo = linearFiberChannel(sigTxo, paramChannel)

# Sinal elétrico (fotocorrente)
I_Rx = photodiode(sigRxo, paramPD)
I_Rx -= I_Rx.mean()

# Sinal elétrico pós-FPF
numtaps = 4096
f1 = paramRF.fc_e - 2*Rs
f2 = paramRF.fc_e + 2*Rs
hbp_RF = firwin(numtaps, (f1, f2), pass_zero = 'bandpass', fs = Fs)

I_RF = firFilter(hbp_RF, I_Rx)

# Sina elétrico pós-PA
IQ_imb = 1 # 10**(1 / 10) * np.exp(1j* 5 * pi/180)

sigRx = hilbert(I_RF)*np.exp(-1j*2*pi*paramRF.fc_e*t)
sigRx = sigRx.real + 1j*sigRx.imag * IQ_imb

gain_pre_PA = 10**( np.log10(dBm2W(paramRF.Pin_PA)/signal_power(sigRx))/2)
sigRx *= gain_pre_PA

sigRx = power_amplifier(sigRx)

sigRx_PA = sigRx.copy()
sigRx_PA = pnorm(sigRx_PA)

numtaps = 4096
hlp = firwin(numtaps, Rs/1.75, fs = Fs)
sigRx = firFilter(hlp, sigRx)

delay = finddelay(sigRx, sigTx)
sigRx = np.roll(sigRx, -delay)

rot = np.mean(sigTx/sigRx)
sigRx = rot/np.abs(rot)*sigRx

# %%
# Param RoF
paramRoF = parameters()
paramRoF.SpS = SpS
paramRoF.Fs  = Fs
paramRoF.Rs  = Rs
paramRoF.IQ_imb = IQ_imb
paramRoF.G_list = (gain_pre_MZM, gain_pre_PA)
paramRoF.paramMZM = paramMZM
paramRoF.paramChannel = paramChannel
paramRoF.paramRF = paramRF
paramRoF.paramPD = paramPD

# %% [markdown]
# ### 3 Preparação do conjunto de dados de treinamento

# %%
SpS_nn = 4

paramDec = parameters()
paramDec.SpS_in = SpS
paramDec.SpS_out = SpS_nn

hlp = firwin(numtaps, SpS_nn*Rs/2, fs = Fs)

sigRef = decimate(pnorm(firFilter(hlp, sigTx)), paramDec).ravel()
sigIn  = decimate(pnorm(sigRx_PA), paramDec).ravel()

delay = finddelay(sigIn, sigRef)
sigIn = np.roll(sigIn, -delay)

rot = np.mean(sigRef/sigIn)
sigIn = rot/np.abs(rot)*sigIn

# %%
sigRef = th.from_numpy(sigRef).to(device).type(th.complex64)
sigIn  = th.from_numpy(sigIn).to(device).type(th.complex64)

# %% [markdown]
# ### 4 - Arquitetura de Aprendizado Indireto (ILA)

# %%
paramILA = parameters()

paramILA.DPD = "KAN"
paramILA.N = 50_000

paramILA.divByL = 1
paramILA.trainTestFrac = 0.75
paramILA.shuffle = False

paramILA.includeMemory = True
paramILA.augment = False

paramILA.device = device
paramILA.pgrsBar = False
paramILA.directLearn = False

paramILA.batch_size = 1_000
paramILA.lr = 5e-3
paramILA.epochs = 100

paramILA.SpS_DPD = 4
paramILA.Ntaps = 4
paramILA.K = 0
paramILA.k = 2
paramILA.grid = 5
paramILA.seed = 0
paramILA.layers = [2*paramILA.Ntaps, 5, 2]
paramILA.RoF_model = None
paramILA.pruning_epochs = []
paramILA.envelope = False

# %%
attr_test = parameters()
attr_test.symbTx    = symbTx
attr_test.paramRoF  = paramRoF
attr_test.paramOFDM = paramOFDM
attr_test.paramDPD  = paramILA

attr_train = parameters()
attr_train.sigIn  = sigIn
attr_train.sigRef = sigRef
attr_train.paramDPD = paramILA

# %%
from tqdm import tqdm
from functools import partialmethod

tqdm.__init__ = partialmethod(tqdm.__init__, disable=True)

# %%
n_trials  = 300
n_studies = np.array([2])
timeout = 60*60*20
save = True

for i, std in enumerate(n_studies):
    print(f"Study {std}:")

    objective_ILA = partial(objective_dpd, attr_test = attr_test, attr_train = attr_train, metrics = ["EVM", "NFLOPs"],
                            model_path = file_path + f"\\ILA\\Study_{std}\\Models")
    
    study_ILA = optuna.create_study(directions=["minimize", "minimize"], sampler = optuna.samplers.TPESampler())
    study_ILA.optimize(objective_ILA, n_trials = n_trials, timeout = timeout, show_progress_bar = True)
    
    complete_trials   = study_ILA.get_trials(deepcopy = False, states = [TrialState.COMPLETE])
    n_complete_trials = len(complete_trials)
    
    study_N1      = np.zeros(n_complete_trials)
    study_Ntaps   = np.zeros(n_complete_trials)
    study_k       = np.zeros(n_complete_trials)
    study_grid    = np.zeros(n_complete_trials)
    study_Nlayers = np.zeros(n_complete_trials)
    
    study_EVM    = np.zeros(n_complete_trials)
    #study_ACLR   = np.zeros(n_complete_trials)
    study_NFLOPs = np.zeros(n_complete_trials)
    
    for j in range(n_complete_trials):
        trials_params    = complete_trials[j].params
        study_EVM[j]     = complete_trials[j].values[0]
        #study_ACLR[j]    = complete_trials[j].values[1]
        study_NFLOPs[j]  = complete_trials[j].values[1]
        
        study_N1[j]      = trials_params["N1"]
        study_Ntaps[j]   = trials_params["Ntaps"]
        study_k[j]       = trials_params["k"]
        study_grid[j]    = trials_params["grid"]
        study_Nlayers[j] = trials_params["Nlayers"]
    
    if save:
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Parameters\\N1.txt', study_N1, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Parameters\\Ntaps.txt', study_Ntaps, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Parameters\\k.txt', study_k, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Parameters\\grid.txt', study_grid, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Parameters\\Nlayers.txt', study_Nlayers, fmt = '%f')
        #np.savetxt(file_path + f'\\ILA\\Study_{std}\\Results\\ACLR.txt', study_ACLR, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Results\\EVM.txt', study_EVM, fmt = '%f')
        np.savetxt(file_path + f'\\ILA\\Study_{std}\\Results\\NFLOps.txt', study_NFLOPs, fmt = '%f')
# Out:
# Study 2:
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
study_ACLR = np.array([ np.loadtxt(file_path + f"\\ILA\\Study_{n_studies[0]}\\Models\\metrics_{i+1}.txt")[1] for i in range(n_trials) ])

# %%
fig, axs = plt.subplots(1, 2, figsize = (14, 5))

# EVM vs NFLOPs
pareto_solutions_evm, pareto_trials_evm = get_pareto(study_EVM, study_NFLOPs, n_trials)

axs[0].scatter(study_NFLOPs, study_EVM, color = "gray", alpha = 0.6)
axs[0].plot(pareto_solutions_evm[:,1], pareto_solutions_evm[:,0], "-o", color = "r")

#axs[0].set_xlim(0, 5e3)
#axs[0].set_ylim(2., 10)
axs[0].set_xlabel("NFLOP's", fontsize = 18)
axs[0].set_ylabel("EVM [%]", fontsize = 18)

axs[0].minorticks_on()
axs[0].tick_params(axis = 'both', top = "True", right = "True", which='minor',  width=1, direction = "in")
axs[0].tick_params(axis = 'both', top = "True", right = "True", which='major',  width=1.5, direction = "in")
axs[0].grid()

# ACLR vs NFLOPs
pareto_solutions_aclr, pareto_trials_aclr = get_pareto(study_ACLR, study_NFLOPs, n_trials)

axs[1].scatter(study_NFLOPs, study_ACLR, color = "gray", alpha = 0.6)
axs[1].plot(pareto_solutions_aclr[:,1], pareto_solutions_aclr[:,0], "-o", color = "r")

#axs[1].set_xlim(0, 5e3)
#axs[1].set_ylim(-32, -25)
axs[1].set_xlabel("NFLOP's", fontsize = 18)
axs[1].set_ylabel("ACLR [dB]", fontsize = 18)

axs[1].minorticks_on()
axs[1].tick_params(axis = 'both', top = "True", right = "True", which='minor',  width=1, direction = "in")
axs[1].tick_params(axis = 'both', top = "True", right = "True", which='major',  width=1.5, direction = "in")
axs[1].grid()

plt.tight_layout()
#plt.savefig(file_path + "\\Plots\\plot_pareto_EVM.png")

# %%
# Pareto Trials - EVM vs NFLOPs

for i, trial in enumerate(pareto_trials_evm):
    print(f"Trial {trial}: EVM = {study_EVM[trial]:.3f} %, NFLOPs = {study_NFLOPs[trial]}")
# Out:
# Trial 5: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 12: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 14: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 16: EVM = 3.080 %, NFLOPs = 8718.0
# Trial 31: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 34: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 35: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 36: EVM = 6.582 %, NFLOPs = 776.0
# Trial 37: EVM = 6.582 %, NFLOPs = 776.0
# Trial 41: EVM = 6.582 %, NFLOPs = 776.0
# Trial 42: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 43: EVM = 6.582 %, NFLOPs = 776.0
# Trial 44: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 47: EVM = 6.582 %, NFLOPs = 776.0
# Trial 59: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 61: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 64: EVM = 6.582 %, NFLOPs = 776.0
# Trial 66: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 68: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 84: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 85: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 86: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 87: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 88: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 89: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 91: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 92: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 93: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 95: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 98: EVM = 6.582 %, NFLOPs = 776.0
# Trial 99: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 102: EVM = 6.582 %, NFLOPs = 776.0
# Trial 105: EVM = 6.582 %, NFLOPs = 776.0
# Trial 111: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 112: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 113: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 115: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 121: EVM = 2.905 %, NFLOPs = 12420.0
# Trial 122: EVM = 2.905 %, NFLOPs = 12420.0
# Trial 124: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 125: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 126: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 130: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 134: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 137: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 138: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 139: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 140: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 141: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 142: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 143: EVM = 2.931 %, NFLOPs = 8880.0
# Trial 149: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 159: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 160: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 162: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 164: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 167: EVM = 3.112 %, NFLOPs = 3600.0
# Trial 168: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 171: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 176: EVM = 6.582 %, NFLOPs = 776.0
# Trial 178: EVM = 6.582 %, NFLOPs = 776.0
# Trial 180: EVM = 6.582 %, NFLOPs = 776.0
# Trial 182: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 183: EVM = 3.105 %, NFLOPs = 5340.0
# Trial 184: EVM = 3.105 %, NFLOPs = 5340.0
# Trial 185: EVM = 3.105 %, NFLOPs = 5340.0
# Trial 188: EVM = 3.105 %, NFLOPs = 5340.0
# Trial 189: EVM = 4.277 %, NFLOPs = 2160.0
# Trial 190: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 195: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 197: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 198: EVM = 6.582 %, NFLOPs = 776.0
# Trial 199: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 202: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 203: EVM = 6.582 %, NFLOPs = 776.0
# Trial 206: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 209: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 210: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 223: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 224: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 228: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 229: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 235: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 237: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 239: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 241: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 242: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 243: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 246: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 247: EVM = 3.081 %, NFLOPs = 8640.0
# Trial 259: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 262: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 266: EVM = 3.200 %, NFLOPs = 2508.0
# Trial 271: EVM = 3.200 %, NFLOPs = 2508.0
# Trial 277: EVM = 3.200 %, NFLOPs = 2508.0
# Trial 281: EVM = 4.756 %, NFLOPs = 1164.0
# Trial 287: EVM = 3.882 %, NFLOPs = 2288.0
# Trial 288: EVM = 6.582 %, NFLOPs = 776.0
# Trial 289: EVM = 4.513 %, NFLOPs = 1726.0
# Trial 293: EVM = 6.582 %, NFLOPs = 776.0
# Trial 296: EVM = 6.582 %, NFLOPs = 776.0
# Trial 298: EVM = 3.081 %, NFLOPs = 8640.0

# %%
# Pareto Trials - ACLR vs NFLOPs

for i, trial in enumerate(pareto_trials_aclr):
    print(f"Trial {trial}: ACLR = {study_ACLR[trial]:.3f} dB, NFLOPs = {study_NFLOPs[trial]}")
# Out:
# Trial 5: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 12: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 25: ACLR = -31.417 dB, NFLOPs = 3220.0
# Trial 31: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 32: ACLR = -31.417 dB, NFLOPs = 3220.0
# Trial 33: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 34: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 35: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 36: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 37: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 41: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 42: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 43: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 44: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 47: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 49: ACLR = -31.417 dB, NFLOPs = 3220.0
# Trial 51: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 52: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 59: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 64: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 65: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 66: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 68: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 77: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 80: ACLR = -31.417 dB, NFLOPs = 3220.0
# Trial 84: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 85: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 86: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 87: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 88: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 89: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 91: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 92: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 93: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 95: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 97: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 98: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 99: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 100: ACLR = -31.417 dB, NFLOPs = 3220.0
# Trial 102: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 105: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 111: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 112: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 159: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 160: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 161: ACLR = -31.499 dB, NFLOPs = 4280.0
# Trial 162: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 168: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 171: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 176: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 178: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 180: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 190: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 195: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 197: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 198: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 199: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 202: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 203: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 206: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 209: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 210: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 223: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 224: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 228: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 229: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 235: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 237: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 239: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 241: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 242: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 243: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 246: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 259: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 262: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 266: ACLR = -31.176 dB, NFLOPs = 2508.0
# Trial 271: ACLR = -31.176 dB, NFLOPs = 2508.0
# Trial 277: ACLR = -31.176 dB, NFLOPs = 2508.0
# Trial 281: ACLR = -28.858 dB, NFLOPs = 1164.0
# Trial 287: ACLR = -30.373 dB, NFLOPs = 2288.0
# Trial 288: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 289: ACLR = -29.281 dB, NFLOPs = 1726.0
# Trial 293: ACLR = -27.298 dB, NFLOPs = 776.0
# Trial 296: ACLR = -27.298 dB, NFLOPs = 776.0
